# %%
# !pip install langchain
# !pip install langgraph
# !pip install chromadb
# !pip install pypdf
# !pip install sentence-transformers
# !pip install transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.2/23.2 MB 61.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 19.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 78.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 72.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.1/72.1 kB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.2/180.2 kB 14.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.0/69.0 kB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.6/231.6 kB 18.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 4.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opentelemetry-proto
#     Found existing installation: opentelemetry-proto 1.38.0
# ...

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-0ea6e5c5-251d-4bfd-b714-750c1b6c3e11" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0ea6e5c5-251d-4bfd-b714-750c1b6c3e11">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ### Loading pdf

# %%
# !pip install langchain langchain-community langchain-core
# !pip install langgraph chromadb pypdf sentence-transformers transformers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 60.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 45.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 515.1/515.1 kB 27.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 3.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.2.28
#     Uninstalling langchain-core-1.2.28:
#       Successfully uninstalled langchain-core-1.2.28
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader("customer_support_knowledge_base.pdf")

documents = loader.load()

print("Total Pages:", len(documents))
# Out:
# Total Pages: 5

# %% [markdown]
# ## chunk split

# %%
# !pip install langchain-text-splitters

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

# Create text splitter
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=50
)

# Split documents
chunks = text_splitter.split_documents(documents)

print("Total Chunks Created:", len(chunks))
# Out:
# Total Chunks Created: 10

# %% [markdown]
# ## create  Embeddings + Store in ChromaDB

# %%
from langchain_community.vectorstores import Chroma
from langchain_community.embeddings import HuggingFaceEmbeddings

# Create embedding model
embedding_model = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

# Store chunks into ChromaDB
vectorstore = Chroma.from_documents(
    documents=chunks,
    embedding=embedding_model
)

print("Vector Database Created Successfully")
# Out:
# /tmp/ipykernel_20724/3049000704.py:5: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the `langchain-huggingface package and should be used instead. To use it run `pip install -U `langchain-huggingface` and import as `from `langchain_huggingface import HuggingFaceEmbeddings``.
#   embedding_model = HuggingFaceEmbeddings(
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:93: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...

# %% [markdown]
# ## Retriever

# %%
retriever = vectorstore.as_retriever()

print("Retriever Ready")
# Out:
# Retriever Ready

# %% [markdown]
# ## LLM + Query Answer System

# %%
def get_context(query):
    docs = retriever.invoke(query)

    # take only top 2 chunks
    return "\n".join([d.page_content for d in docs[:2]])

# %%
def generate_answer(query):

    context = get_context(query)

    # break into lines
    lines = context.split("\n")

    # keep only meaningful lines
    clean_lines = []

    for l in lines:
        if len(l) > 25 and "Customers" in l or "Order" in l or "Refund" in l or "Cancel" in l:
            clean_lines.append(l.strip())

    # fallback if filter is empty
    if not clean_lines:
        clean_lines = [l for l in lines if len(l) > 20]

    return "\n".join(clean_lines[:5])

# %%
print(generate_answer("How do I cancel my order?"))
# Out:
# Cancellation Steps:
# Open My Orders.
# Click Cancel Order.
# Refund will be initiated immediately after cancellation.
# Customers can pay using multiple payment methods.

# %%
print(generate_answer("what is Refund Timeline?"))
# Out:
# You can return a product within 7 days by visiting My Orders and requesting a return.
# Refunds are processed within 7–10 working days.
# Use the tracking ID available in My Orders.
# No. Orders cannot be cancelled once shipped.
# 3. Refund Policy

# %%
print(generate_answer("What is refund policy?"))
# Out:
# 3. Refund Policy
# Refunds are issued after the returned product is received and inspected.
# Refund Methods:
# Refunds are processed using the original payment method:
# Refund Timeline:

# %% [markdown]
# ## Human_In_The_Loop (HITL)

# %%
from transformers import pipeline

# Clean generator setup
generator = pipeline(
    task="text-generation",
    model="gpt2",
    max_new_tokens=120
)
# Out:
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]

# %%
def generate_answer(query):

    # Retrieve documents
    docs = retriever.invoke(query)

    if not docs:
        return "⚠️ Escalating to Human Support (HITL): No relevant information found."

    # Combine text
    context = " ".join([doc.page_content for doc in docs])

    context_clean = context.lower()
    query_clean = query.lower()

    # Keywords expected in customer support PDF
    keywords = [
        "cancel",
        "refund",
        "track",
        "order",
        "payment",
        "return",
        "shipping"
    ]

    # Check if query contains known keywords
    if not any(word in query_clean for word in keywords):
        return "⚠️ Escalating to Human Support (HITL): Query not related to knowledge base."

    # Clean formatting
    context = context.replace("\n", " ")

    # Limit answer size
    answer = context[:250]

    return answer

# %%
generate_answer("what is CEO Salary?")
# Out:
# '⚠️ Escalating to Human Support (HITL): Query not related to knowledge base.'
